# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
df = pd.read_csv(r'C:\Users\Hydr\Desktop\Data Science\ML for Statistics\Assignment\Car_sales.csv')

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
# find duplicated rows 
df.duplicated().sum()
# Out:
# 0

# %%
#identify Missing values 

for column in df.columns:
    print(f"Column name: {column}, Missing values: {df[column].isnull().sum()}")
    print("----------")
# Out:
# Column name: Manufacturer, Missing values: 0
# ----------
# Column name: Model, Missing values: 0
# ----------
# Column name: Sales_in_thousands, Missing values: 0
# ----------
# Column name: __year_resale_value, Missing values: 36
# ----------
# Column name: Vehicle_type, Missing values: 0
# ----------
# Column name: Price_in_thousands, Missing values: 2
# ----------
# Column name: Engine_size, Missing values: 1
# ----------
# Column name: Horsepower, Missing values: 1
# ----------
# Column name: Wheelbase, Missing values: 1
# ----------
# Column name: Width, Missing values: 1
# ----------
# Column name: Length, Missing values: 1
# ----------
# Column name: Curb_weight, Missing values: 2
# ----------
# Column name: Fuel_capacity, Missing values: 1
# ----------
# Column name: Fuel_efficiency, Missing values: 3
# ----------
# Column name: Latest_Launch, Missing values: 0
# ----------
# Column name: Power_perf_factor, Missing values: 2
# ----------

# %%
# Drop rows with any missing values
df1= df.dropna()

# %%
df1
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
# Identify the variable types in the given data set.
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 117 entries, 0 to 149
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Latest_Launch        117 non-null    object
# ...

# %%
# Identify the variable types in the given data set.
print(df1.dtypes)
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# dtype: object

# %%
# Make a bar graph for manufacturer type

# Assuming 'manufacturer' is the column name for manufacturer type
# Count the occurrences of each manufacturer
manufacturer_counts = df['Manufacturer'].value_counts()

# Plotting
plt.figure(figsize=(10, 8))  # Adjust the size as needed
manufacturer_counts.plot(kind='bar')
plt.title('Manufacturer Type Distribution')
plt.xlabel('Manufacturer')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotate labels to make them readable
plt.show()

# %%
#• 	Make a pie chart for showing vehicle type by percentage

vehicle_type_counts = df['Vehicle_type'].value_counts()

# Plotting
plt.figure(figsize=(10, 7))  # Adjusts the size of the figure
plt.pie(vehicle_type_counts, labels = vehicle_type_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Vehicle Type Distribution')
plt.show()

# %%
# •	Calculate average Price of all cars by using correct measure of central Tendency

print(df['Price_in_thousands'].describe())

# To visualize the distribution of car prices


plt.hist(df['Price_in_thousands'], bins=20, edgecolor='black')
plt.title('Distribution of Car Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()
# Out:
# count    155.000000
# mean      27.390755
# std       14.351653
# min        9.235000
# 25%       18.017500
# 50%       22.799000
# 75%       31.947500
# max       85.500000
# Name: Price_in_thousands, dtype: float64

# %%
# median since skewed 

median_price = df['Price_in_thousands'].median()

print(f"Average Price of all cars: {median_price}")
# Out:
# Average Price of all cars: 22.799

# %%
for column in float_columns:
    # Calculate variance and standard deviation for each column individually
    variance = df[column].var()
    std_deviation = df[column].std()
    print(f"Column: {column}")
    print("Standard Deviation:", std_deviation)
    print("Variance:", variance)
    print("----------")
# Out:
# Column: Sales_in_thousands
# Standard Deviation: 68.02942199750512
# Variance: 4628.002257314634
# ----------
# Column: __year_resale_value
# Standard Deviation: 11.453384099225005
# Variance: 131.18000732438017
# ----------
# Column: Price_in_thousands
# Standard Deviation: 14.351653189238549
# Variance: 205.96994926418103
# ----------
# Column: Engine_size
# Standard Deviation: 1.0446529732758283
# Variance: 1.0912998345740283
# ----------
# Column: Horsepower
# Standard Deviation: 56.70032085837359
# Variance: 3214.926385442515
# ----------
# Column: Wheelbase
# Standard Deviation: 7.641303029809964
# Variance: 58.38951199338294
# ----------
# Column: Width
# Standard Deviation: 3.4518718624593676
# Variance: 11.915419354838704
# ----------
# Column: Length
# Standard Deviation: 13.431754284516824
# Variance: 180.41202315963608
# ----------
# Column: Curb_weight
# Standard Deviation: 0.6305016344292964
# Variance: 0.3975323110180142
# ----------
# Column: Fuel_capacity
# ...

# %%
# •	For the same columns Calculate IQR and identify outliers in these columns
for column in float_columns:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Identifying outliers
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    
    print(f"Column: {column}")
    print(f"IQR: {IQR}")
    if not outliers.empty:
        print(f"Number of outliers in {column}: {len(outliers)}")
    else:
        print(f"No outliers found in {column}")
    print("----------")
# Out:
# Column: Sales_in_thousands
# IQR: 53.842
# Number of outliers in Sales_in_thousands: 12
# ----------
# Column: __year_resale_value
# IQR: 8.615
# Number of outliers in __year_resale_value: 12
# ----------
# Column: Price_in_thousands
# IQR: 13.93
# Number of outliers in Price_in_thousands: 9
# ----------
# Column: Engine_size
# IQR: 1.2750000000000004
# Number of outliers in Engine_size: 3
# ----------
# Column: Horsepower
# IQR: 65.5
# Number of outliers in Horsepower: 2
# ----------
# Column: Wheelbase
# IQR: 9.200000000000003
# Number of outliers in Wheelbase: 4
# ----------
# Column: Width
# IQR: 5.025000000000006
# No outliers found in Width
# ----------
# Column: Length
# IQR: 18.55000000000001
# Number of outliers in Length: 3
# ----------
# Column: Curb_weight
# IQR: 0.8285
# Number of outliers in Curb_weight: 4
# ----------
# Column: Fuel_capacity
# IQR: 3.7749999999999986
# Number of outliers in Fuel_capacity: 9
# ----------
# Column: Fuel_efficiency
# IQR: 5.0
# ...

# %%
# •	Make Histograms for all Numerical columns and identify the distribution of type by calculating skewness; 


for column in float_columns:
    # Plotting the histogram
    plt.figure(figsize=(10, 6))
    df[column].hist(bins=30)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    
    # Display the plot
    plt.show()
    
    # Calculating skewness
    skewness = df[column].skew()
    print(f'Skewness of {column}: {skewness}')
    if skewness > 0:
        print(f'{column} is positively skewed\n')
    elif skewness < 0:
        print(f'{column} is negatively skewed\n')
    else:
        print(f'{column} is approximately symmetric\n')
# Out:
# Skewness of Sales_in_thousands: 3.408518366470572
# Sales_in_thousands is positively skewed
# Skewness of __year_resale_value: 2.2949154931263167
# __year_resale_value is positively skewed
# Skewness of Price_in_thousands: 1.765734331031903
# Price_in_thousands is positively skewed
# Skewness of Engine_size: 1.1004473434089452
# Engine_size is positively skewed
# Skewness of Horsepower: 1.000694991792015
# Horsepower is positively skewed
# Skewness of Wheelbase: 0.9699356566005035
# Wheelbase is positively skewed
# Skewness of Width: 0.4838620694150985
# Width is positively skewed
# Skewness of Length: -0.05904682306640935
# Length is negatively skewed
# Skewness of Curb_weight: 0.7081582403603772
# Curb_weight is positively skewed
# Skewness of Fuel_capacity: 1.136712405715284
# Fuel_capacity is positively skewed
# Skewness of Fuel_efficiency: 0.6923277566877377
# Fuel_efficiency is positively skewed
# Skewness of Power_perf_factor: 1.0706349886819244
# ...
